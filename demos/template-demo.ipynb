# %% [markdown]
# # High-level demonstration of what the code in this repo does
#
# This notebook is a template.

# %%
from templatecode import sayhi # import as a library

sayhi.hello()

# %% [markdown]
# Dida Markovic, 2025
